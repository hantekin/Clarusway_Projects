# %% [markdown]
# <h1 style="text-align: center;"><br>Image Classification with CNN<br><br>Cat-Dog Classification Project<br><h1>

# %% [markdown]
# # Dataset Info

# %% [markdown]
# The Dogs vs. Cats dataset is a common computer vision dataset in which pictures are classified as either including a dog or a cat.
#
# After the dataset is well studied, it can be used to understand and practice how to design, evaluate, and apply convolutional neural networks for image classification.
#
# We will build a classifier with images and try to detect dogs versus cats using CNN.
#
# Train set includes 12500 cat-5026 dog images, validation set includes 1219 cat-1071 dog images and test set incgludes 6897 cat and dogs images together.

# %% [markdown]
# # Import Libraries and Export Images from Zip_File

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

#import warnings
#warnings.filterwarnings("ignore")
#warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
import tensorflow as tf

tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Unzip the file
zip_ref = zipfile.ZipFile("/content/drive/MyDrive/Colab Notebooks/CNN Project-Image Classification with CNN (catdogclassifier)/cat_dog_data.zip", "r")
zip_ref.extractall()
zip_ref.close()

# %% [markdown]
# # Recognizing and Understanding Data

# %%
my_data_dir = 'data'

# %%
os.listdir(my_data_dir)
# Out:
# ['train', 'test', 'validation']

# %%
val_path = my_data_dir+'/validation/'
train_path = my_data_dir+'/train/'
test_path = my_data_dir+'/test/'

# %%
os.listdir(train_path)
# Out:
# ['dog', 'cat']

# %%
os.listdir(val_path)
# Out:
# ['dog', 'cat']

# %%
os.listdir(test_path)[:5]
# Out:
# ['4703.jpg', '3669.jpg', '5386.jpg', '3143.jpg', '3252.jpg']

# %%
import pathlib

data_dir = pathlib.Path(train_path) # turn our training path into a Python path
class_names = np.array(sorted([item.name for item in data_dir.glob('*')])) # created a list of class_names from the subdirectories
print(class_names)
# Out:
# ['cat' 'dog']

# %% [markdown]
# **Let's check how many images there are.**

# %%
os.listdir(train_path+'cat')
# Out:
# ['cat.1434.jpg',
#  'cat.7828.jpg',
#  'cat.3710.jpg',
#  'cat.11175.jpg',
#  'cat.866.jpg',
#  'cat.6376.jpg',
#  'cat.7308.jpg',
#  'cat.11219.jpg',
#  'cat.5125.jpg',
#  'cat.5298.jpg',
#  'cat.6773.jpg',
#  'cat.10597.jpg',
#  'cat.910.jpg',
#  'cat.2389.jpg',
#  'cat.8469.jpg',
#  'cat.4464.jpg',
#  'cat.6006.jpg',
#  'cat.3957.jpg',
#  'cat.11203.jpg',
#  'cat.9602.jpg',
#  'cat.3947.jpg',
#  'cat.7498.jpg',
#  'cat.9312.jpg',
#  'cat.5602.jpg',
#  'cat.7593.jpg',
#  'cat.5721.jpg',
#  'cat.377.jpg',
#  'cat.8450.jpg',
#  'cat.8418.jpg',
#  'cat.8694.jpg',
#  'cat.2985.jpg',
#  'cat.2969.jpg',
#  'cat.10937.jpg',
#  'cat.3348.jpg',
#  'cat.7726.jpg',
#  'cat.11099.jpg',
#  'cat.9643.jpg',
#  'cat.9843.jpg',
#  'cat.8263.jpg',
#  'cat.1916.jpg',
#  'cat.4883.jpg',
#  'cat.7827.jpg',
#  'cat.9396.jpg',
#  'cat.4129.jpg',
#  'cat.9425.jpg',
#  'cat.1555.jpg',
#  'cat.272.jpg',
#  'cat.5517.jpg',
#  'cat.10825.jpg',
#  'cat.2667.jpg',
#  'cat.872.jpg',
#  'cat.1312.jpg',
#  'cat.7075.jpg',
#  'cat.5729.jpg',
#  'cat.4672.jpg',
#  'cat.5277.jpg',
#  'cat.8540.jpg',
#  'cat.7995.jpg',
#  'cat.11689.jpg',
#  'cat.4451.jpg',
#  'cat.10787.jpg',
#  'cat.2310.jpg',
#  'cat.325.jpg',
#  'cat.844.jpg',
#  'cat.7362.jpg',
#  'cat.8398.jpg',
#  'cat.7607.jpg',
#  'cat.8902.jpg',
#  'cat.10007.jpg',
#  'cat.2824.jpg',
#  'cat.7397.jpg',
#  'cat.26.jpg',
#  'cat.4702.jpg',
#  'cat.10997.jpg',
#  'cat.9807.jpg',
#  'cat.7322.jpg',
#  'cat.5416.jpg',
#  'cat.7754.jpg',
#  'cat.3870.jpg',
#  'cat.6686.jpg',
#  'cat.6343.jpg',
#  'cat.2492.jpg',
#  'cat.4935.jpg',
#  'cat.8739.jpg',
#  'cat.3578.jpg',
#  'cat.3670.jpg',
#  'cat.7662.jpg',
#  'cat.236.jpg',
#  'cat.8562.jpg',
#  'cat.5314.jpg',
#  'cat.11745.jpg',
#  'cat.6499.jpg',
#  'cat.1101.jpg',
#  'cat.4566.jpg',
#  'cat.5479.jpg',
#  'cat.1207.jpg',
#  'cat.1683.jpg',
#  'cat.3889.jpg',
#  'cat.2248.jpg',
#  'cat.11579.jpg',
#  'cat.5482.jpg',
#  'cat.9943.jpg',
#  'cat.9685.jpg',
#  'cat.8013.jpg',
#  'cat.6474.jpg',
#  'cat.4997.jpg',
#  'cat.5151.jpg',
#  'cat.10800.jpg',
#  'cat.10432.jpg',
#  'cat.6404.jpg',
#  'cat.8035.jpg',
#  'cat.8363.jpg',
#  'cat.8237.jpg',
#  'cat.109.jpg',
#  'cat.9412.jpg',
#  'cat.2453.jpg',
#  'cat.11950.jpg',
#  'cat.12200.jpg',
#  'cat.6153.jpg',
#  'cat.3307.jpg',
#  'cat.7250.jpg',
#  'cat.10718.jpg',
#  'cat.1100.jpg',
#  'cat.11726.jpg',
#  'cat.11671.jpg',
#  'cat.12239.jpg',
#  'cat.1375.jpg',
#  'cat.3941.jpg',
#  'cat.6040.jpg',
#  'cat.9852.jpg',
#  'cat.4800.jpg',
#  'cat.1981.jpg',
#  'cat.750.jpg',
#  'cat.6607.jpg',
#  'cat.1267.jpg',
#  'cat.10516.jpg',
#  'cat.10580.jpg',
#  'cat.3028.jpg',
#  'cat.299.jpg',
#  'cat.8388.jpg',
#  'cat.1574.jpg',
#  'cat.4259.jpg',
#  'cat.12362.jpg',
#  'cat.11699.jpg',
#  'cat.2161.jpg',
#  'cat.9459.jpg',
#  'cat.11447.jpg',
#  'cat.6664.jpg',
#  'cat.3881.jpg',
#  'cat.10269.jpg',
#  'cat.3160.jpg',
#  'cat.1384.jpg',
#  'cat.8465.jpg',
#  'cat.519.jpg',
#  'cat.1006.jpg',
#  'cat.7875.jpg',
#  'cat.11368.jpg',
#  'cat.889.jpg',
#  'cat.7566.jpg',
#  'cat.4633.jpg',
#  'cat.4929.jpg',
#  'cat.5905.jpg',
#  'cat.3327.jpg',
#  'cat.4899.jpg',
#  'cat.5441.jpg',
#  'cat.9050.jpg',
#  'cat.19.jpg',
#  'cat.8225.jpg',
#  'cat.12337.jpg',
#  'cat.8947.jpg',
#  'cat.2154.jpg',
#  'cat.12294.jpg',
#  'cat.3705.jpg',
#  'cat.4472.jpg',
#  'cat.5333.jpg',
#  'cat.8106.jpg',
#  'cat.7704.jpg',
#  'cat.6497.jpg',
#  'cat.7824.jpg',
#  'cat.204.jpg',
#  'cat.2659.jpg',
#  'cat.1661.jpg',
#  'cat.6432.jpg',
#  'cat.3456.jpg',
#  'cat.11028.jpg',
#  'cat.4905.jpg',
#  'cat.9554.jpg',
#  'cat.699.jpg',
#  'cat.10596.jpg',
#  'cat.11084.jpg',
#  'cat.4895.jpg',
#  'cat.10396.jpg',
#  'cat.10206.jpg',
#  'cat.3357.jpg',
#  'cat.3016.jpg',
#  'cat.4915.jpg',
#  'cat.5150.jpg',
#  'cat.3892.jpg',
#  'cat.625.jpg',
#  'cat.9279.jpg',
#  'cat.4734.jpg',
#  'cat.9932.jpg',
#  'cat.5771.jpg',
#  'cat.2899.jpg',
#  'cat.7468.jpg',
#  'cat.2897.jpg',
#  'cat.8998.jpg',
#  'cat.7463.jpg',
#  'cat.4549.jpg',
#  'cat.8397.jpg',
#  'cat.521.jpg',
#  'cat.3330.jpg',
#  'cat.8081.jpg',
#  'cat.6019.jpg',
#  'cat.4450.jpg',
#  'cat.8037.jpg',
#  'cat.7293.jpg',
#  'cat.7829.jpg',
#  'cat.1278.jpg',
#  'cat.4775.jpg',
#  'cat.1462.jpg',
#  'cat.4387.jpg',
#  'cat.7224.jpg',
#  'cat.1148.jpg',
#  'cat.8525.jpg',
#  'cat.931.jpg',
#  'cat.7384.jpg',
#  'cat.9002.jpg',
#  'cat.10438.jpg',
#  'cat.3180.jpg',
#  'cat.1497.jpg',
#  'cat.6267.jpg',
#  'cat.1776.jpg',
#  'cat.7367.jpg',
#  'cat.4149.jpg',
#  'cat.45.jpg',
#  'cat.9442.jpg',
#  'cat.1635.jpg',
#  'cat.3819.jpg',
#  'cat.11995.jpg',
#  'cat.5758.jpg',
#  'cat.1759.jpg',
#  'cat.9591.jpg',
#  'cat.6730.jpg',
#  'cat.11355.jpg',
#  'cat.8571.jpg',
#  'cat.11154.jpg',
#  'cat.10583.jpg',
#  'cat.5578.jpg',
#  'cat.10983.jpg',
#  'cat.11018.jpg',
#  'cat.4488.jpg',
#  'cat.12311.jpg',
#  'cat.2793.jpg',
#  'cat.8611.jpg',
#  'cat.9043.jpg',
#  'cat.8751.jpg',
#  'cat.8687.jpg',
#  'cat.3544.jpg',
#  'cat.6625.jpg',
#  'cat.9512.jpg',
#  'cat.5853.jpg',
#  'cat.8361.jpg',
#  'cat.5259.jpg',
#  'cat.1226.jpg',
#  'cat.8736.jpg',
#  'cat.9013.jpg',
#  'cat.5281.jpg',
#  'cat.8615.jpg',
#  'cat.154.jpg',
#  'cat.3726.jpg',
#  'cat.7843.jpg',
#  'cat.383.jpg',
#  'cat.837.jpg',
#  'cat.5444.jpg',
#  'cat.10956.jpg',
#  'cat.4138.jpg',
#  'cat.135.jpg',
#  'cat.9663.jpg',
#  'cat.576.jpg',
#  'cat.2236.jpg',
#  'cat.734.jpg',
#  'cat.2344.jpg',
#  'cat.12222.jpg',
#  'cat.8631.jpg',
#  'cat.1260.jpg',
#  'cat.3196.jpg',
#  'cat.10501.jpg',
#  'cat.1182.jpg',
#  'cat.6190.jpg',
#  'cat.6374.jpg',
#  'cat.9342.jpg',
#  'cat.9044.jpg',
#  'cat.7386.jpg',
#  'cat.1878.jpg',
#  'cat.4078.jpg',
#  'cat.9635.jpg',
#  'cat.7952.jpg',
#  'cat.4753.jpg',
#  'cat.12260.jpg',
#  'cat.11429.jpg',
#  'cat.8503.jpg',
#  'cat.9837.jpg',
#  'cat.4606.jpg',
#  'cat.10224.jpg',
#  'cat.6347.jpg',
#  'cat.1689.jpg',
#  'cat.5598.jpg',
#  'cat.1655.jpg',
#  'cat.9078.jpg',
#  'cat.11680.jpg',
#  'cat.5203.jpg',
#  'cat.4945.jpg',
#  'cat.4016.jpg',
#  'cat.2041.jpg',
#  'cat.4678.jpg',
#  'cat.3748.jpg',
#  'cat.58.jpg',
#  'cat.8616.jpg',
#  'cat.193.jpg',
#  'cat.8266.jpg',
#  'cat.8706.jpg',
#  'cat.3603.jpg',
#  'cat.3967.jpg',
#  'cat.12072.jpg',
#  'cat.2209.jpg',
#  'cat.12446.jpg',
#  'cat.6405.jpg',
#  'cat.11161.jpg',
#  'cat.8116.jpg',
#  'cat.10171.jpg',
#  'cat.10118.jpg',
#  'cat.1222.jpg',
#  'cat.1994.jpg',
#  'cat.7186.jpg',
#  'cat.451.jpg',
#  'cat.973.jpg',
#  'cat.5194.jpg',
#  'cat.11197.jpg',
#  'cat.9189.jpg',
#  'cat.4861.jpg',
#  'cat.8783.jpg',
#  'cat.7672.jpg',
#  'cat.5033.jpg',
#  'cat.7218.jpg',
#  'cat.6147.jpg',
#  'cat.3888.jpg',
#  'cat.3792.jpg',
#  'cat.4198.jpg',
#  'cat.3797.jpg',
#  'cat.1488.jpg',
#  'cat.7425.jpg',
#  'cat.3874.jpg',
#  'cat.8304.jpg',
#  'cat.5264.jpg',
#  'cat.8636.jpg',
#  'cat.4970.jpg',
#  'cat.1797.jpg',
#  'cat.6416.jpg',
#  'cat.2024.jpg',
#  'cat.390.jpg',
#  'cat.12147.jpg',
#  'cat.12375.jpg',
#  'cat.9320.jpg',
#  'cat.8426.jpg',
#  'cat.8382.jpg',
#  'cat.4719.jpg',
#  'cat.4385.jpg',
#  'cat.8299.jpg',
#  'cat.11364.jpg',
#  'cat.4132.jpg',
#  'cat.10041.jpg',
#  'cat.4083.jpg',
#  'cat.9786.jpg',
#  'cat.7766.jpg',
#  'cat.4251.jpg',
#  'cat.5829.jpg',
#  'cat.6292.jpg',
#  'cat.4050.jpg',
#  'cat.10982.jpg',
#  'cat.11433.jpg',
#  'cat.6282.jpg',
#  'cat.7977.jpg',
#  'cat.7756.jpg',
#  'cat.4823.jpg',
#  'cat.9620.jpg',
#  'cat.10469.jpg',
#  'cat.3277.jpg',
#  'cat.9716.jpg',
#  'cat.907.jpg',
#  'cat.1573.jpg',
#  'cat.6567.jpg',
#  'cat.3708.jpg',
#  'cat.10059.jpg',
#  'cat.5703.jpg',
#  'cat.3369.jpg',
#  'cat.2912.jpg',
#  'cat.7429.jpg',
#  'cat.7870.jpg',
#  'cat.1652.jpg',
#  'cat.7407.jpg',
#  'cat.194.jpg',
#  'cat.9489.jpg',
#  'cat.187.jpg',
#  'cat.6526.jpg',
#  'cat.2557.jpg',
#  'cat.10652.jpg',
#  'cat.4113.jpg',
#  'cat.1996.jpg',
#  'cat.731.jpg',
#  'cat.6704.jpg',
#  'cat.4758.jpg',
#  'cat.2384.jpg',
#  'cat.8785.jpg',
#  'cat.7474.jpg',
#  'cat.1942.jpg',
#  'cat.5824.jpg',
#  'cat.9648.jpg',
#  'cat.6737.jpg',
#  'cat.1253.jpg',
#  'cat.1055.jpg',
#  'cat.2843.jpg',
#  'cat.4445.jpg',
#  'cat.11979.jpg',
#  'cat.4362.jpg',
#  'cat.7736.jpg',
#  'cat.6415.jpg',
#  'cat.6070.jpg',
#  'cat.7904.jpg',
#  'cat.5798.jpg',
#  'cat.687.jpg',
#  'cat.11963.jpg',
#  'cat.10955.jpg',
#  'cat.2937.jpg',
#  'cat.4998.jpg',
#  'cat.8522.jpg',
#  'cat.1321.jpg',
#  'cat.7527.jpg',
#  'cat.2366.jpg',
#  'cat.11144.jpg',
#  'cat.6753.jpg',
#  'cat.8073.jpg',
#  'cat.7624.jpg',
#  'cat.2905.jpg',
#  'cat.9915.jpg',
#  'cat.4470.jpg',
#  'cat.2167.jpg',
#  'cat.11208.jpg',
#  'cat.8478.jpg',
#  'cat.6206.jpg',
#  'cat.9252.jpg',
#  'cat.4661.jpg',
#  'cat.3338.jpg',
#  'cat.8850.jpg',
#  'cat.1206.jpg',
#  'cat.3450.jpg',
#  'cat.260.jpg',
#  'cat.1432.jpg',
#  'cat.400.jpg',
#  'cat.8411.jpg',
#  'cat.10086.jpg',
#  'cat.11419.jpg',
#  'cat.1177.jpg',
#  'cat.11646.jpg',
#  'cat.5985.jpg',
#  'cat.1962.jpg',
#  'cat.2303.jpg',
#  'cat.6542.jpg',
#  'cat.5179.jpg',
#  'cat.4972.jpg',
#  'cat.8100.jpg',
#  'cat.7450.jpg',
#  'cat.556.jpg',
#  'cat.1220.jpg',
#  'cat.2778.jpg',
#  'cat.9358.jpg',
#  'cat.2518.jpg',
#  'cat.1672.jpg',
#  'cat.6902.jpg',
#  'cat.11775.jpg',
#  'cat.4393.jpg',
#  'cat.1251.jpg',
#  'cat.4271.jpg',
#  'cat.2049.jpg',
#  'cat.5741.jpg',
#  'cat.7337.jpg',
#  'cat.8268.jpg',
#  'cat.5610.jpg',
#  'cat.4731.jpg',
#  'cat.7055.jpg',
#  'cat.11166.jpg',
#  'cat.6331.jpg',
#  'cat.797.jpg',
#  'cat.5307.jpg',
#  'cat.8752.jpg',
#  'cat.8175.jpg',
#  'cat.11100.jpg',
#  'cat.7167.jpg',
#  'cat.5009.jpg',
#  'cat.9073.jpg',
#  'cat.8849.jpg',
#  'cat.12183.jpg',
#  'cat.2734.jpg',
#  'cat.2267.jpg',
#  'cat.5373.jpg',
#  'cat.10307.jpg',
#  'cat.10175.jpg',
#  'cat.9069.jpg',
#  'cat.6925.jpg',
#  'cat.9395.jpg',
#  'cat.1738.jpg',
#  'cat.11690.jpg',
#  'cat.10531.jpg',
#  'cat.10760.jpg',
#  'cat.5838.jpg',
#  'cat.4139.jpg',
#  'cat.6812.jpg',
#  'cat.1231.jpg',
#  'cat.6734.jpg',
#  'cat.11235.jpg',
#  'cat.5335.jpg',
#  'cat.5360.jpg',
#  'cat.4684.jpg',
#  'cat.5825.jpg',
#  'cat.162.jpg',
#  'cat.6717.jpg',
#  'cat.8146.jpg',
#  'cat.9861.jpg',
#  'cat.7632.jpg',
#  'cat.4180.jpg',
#  'cat.867.jpg',
#  'cat.5002.jpg',
#  'cat.5367.jpg',
#  'cat.6816.jpg',
#  'cat.7559.jpg',
#  'cat.94.jpg',
#  'cat.4427.jpg',
#  'cat.8962.jpg',
#  'cat.3294.jpg',
#  'cat.398.jpg',
#  'cat.3706.jpg',
#  'cat.7482.jpg',
#  'cat.8238.jpg',
#  'cat.8188.jpg',
#  'cat.8881.jpg',
#  'cat.7639.jpg',
#  'cat.1304.jpg',
#  'cat.2305.jpg',
#  'cat.7908.jpg',
#  'cat.5893.jpg',
#  'cat.3458.jpg',
#  'cat.11803.jpg',
#  'cat.3334.jpg',
#  'cat.6583.jpg',
#  'cat.7253.jpg',
#  'cat.1443.jpg',
#  'cat.4012.jpg',
#  'cat.3085.jpg',
#  'cat.134.jpg',
#  'cat.11116.jpg',
#  'cat.2099.jpg',
#  'cat.10595.jpg',
#  'cat.4059.jpg',
#  'cat.6445.jpg',
#  'cat.9844.jpg',
#  'cat.335.jpg',
#  'cat.5304.jpg',
#  'cat.5470.jpg',
#  'cat.4599.jpg',
#  'cat.88.jpg',
#  'cat.3157.jpg',
#  'cat.9081.jpg',
#  'cat.2815.jpg',
#  'cat.8761.jpg',
#  'cat.8669.jpg',
#  'cat.11607.jpg',
#  'cat.1030.jpg',
#  'cat.5219.jpg',
#  'cat.3509.jpg',
#  'cat.10344.jpg',
#  'cat.12096.jpg',
#  'cat.10866.jpg',
#  'cat.8775.jpg',
#  'cat.9601.jpg',
#  'cat.627.jpg',
#  'cat.7911.jpg',
#  'cat.4893.jpg',
#  'cat.10081.jpg',
#  'cat.6418.jpg',
#  'cat.5310.jpg',
#  'cat.4252.jpg',
#  'cat.8410.jpg',
#  'cat.3630.jpg',
#  'cat.4429.jpg',
#  'cat.8878.jpg',
#  'cat.11285.jpg',
#  'cat.1492.jpg',
#  'cat.7444.jpg',
#  'cat.2881.jpg',
#  'cat.7816.jpg',
#  'cat.3877.jpg',
#  'cat.5074.jpg',
#  'cat.10703.jpg',
#  'cat.4350.jpg',
#  'cat.1736.jpg',
#  'cat.12221.jpg',
#  'cat.11127.jpg',
#  'cat.5081.jpg',
#  'cat.11694.jpg',
#  'cat.5609.jpg',
#  'cat.3587.jpg',
#  'cat.9481.jpg',
#  'cat.6793.jpg',
#  'cat.3654.jpg',
#  'cat.10867.jpg',
#  'cat.3042.jpg',
#  'cat.4953.jpg',
#  'cat.4095.jpg',
#  'cat.4698.jpg',
#  'cat.11466.jpg',
#  'cat.3040.jpg',
#  'cat.2007.jpg',
#  'cat.1315.jpg',
#  'cat.3838.jpg',
#  'cat.2060.jpg',
#  'cat.775.jpg',
#  'cat.6889.jpg',
#  'cat.11856.jpg',
#  'cat.11526.jpg',
#  'cat.10661.jpg',
#  'cat.1361.jpg',
#  'cat.1792.jpg',
#  'cat.8905.jpg',
#  'cat.5718.jpg',
#  'cat.6564.jpg',
#  'cat.7100.jpg',
#  'cat.1468.jpg',
#  'cat.8141.jpg',
#  'cat.4460.jpg',
#  'cat.569.jpg',
#  'cat.2279.jpg',
#  'cat.8143.jpg',
#  'cat.10103.jpg',
#  'cat.10675.jpg',
#  'cat.3971.jpg',
#  'cat.3953.jpg',
#  'cat.4440.jpg',
#  'cat.634.jpg',
#  'cat.4989.jpg',
#  'cat.9925.jpg',
#  'cat.4098.jpg',
#  'cat.10732.jpg',
#  'cat.10617.jpg',
#  'cat.11350.jpg',
#  'cat.6603.jpg',
#  'cat.1889.jpg',
#  'cat.676.jpg',
#  'cat.4476.jpg',
#  'cat.8087.jpg',
#  'cat.5570.jpg',
#  'cat.6503.jpg',
#  'cat.7180.jpg',
#  'cat.11138.jpg',
#  'cat.12141.jpg',
#  'cat.9676.jpg',
#  'cat.12283.jpg',
#  'cat.7597.jpg',
#  'cat.1906.jpg',
#  'cat.1699.jpg',
#  'cat.2688.jpg',
#  'cat.3322.jpg',
#  'cat.7921.jpg',
#  'cat.11282.jpg',
#  'cat.6421.jpg',
#  'cat.6222.jpg',
#  'cat.4414.jpg',
#  'cat.6013.jpg',
#  'cat.6885.jpg',
#  'cat.3942.jpg',
#  'cat.5027.jpg',
#  'cat.9344.jpg',
#  'cat.2315.jpg',
#  'cat.10534.jpg',
#  'cat.12212.jpg',
#  'cat.12126.jpg',
#  'cat.6619.jpg',
#  'cat.9098.jpg',
#  'cat.6928.jpg',
#  'cat.2614.jpg',
#  'cat.2125.jpg',
#  'cat.6475.jpg',
#  'cat.10735.jpg',
#  'cat.12171.jpg',
#  'cat.9241.jpg',
#  'cat.7168.jpg',
#  'cat.5330.jpg',
#  'cat.11058.jpg',
#  'cat.4739.jpg',
#  'cat.1862.jpg',
#  'cat.11000.jpg',
#  'cat.9746.jpg',
#  'cat.6345.jpg',
#  'cat.1876.jpg',
#  'cat.11264.jpg',
#  'cat.4325.jpg',
#  'cat.9211.jpg',
#  'cat.8996.jpg',
#  'cat.11951.jpg',
#  'cat.11296.jpg',
#  'cat.8038.jpg',
#  'cat.6957.jpg',
#  'cat.4614.jpg',
#  'cat.1284.jpg',
#  'cat.12013.jpg',
#  'cat.209.jpg',
#  'cat.2834.jpg',
#  'cat.5079.jpg',
#  'cat.361.jpg',
#  'cat.4964.jpg',
#  'cat.8220.jpg',
#  'cat.4448.jpg',
#  'cat.11900.jpg',
#  'cat.3880.jpg',
#  'cat.7294.jpg',
#  'cat.79.jpg',
#  'cat.892.jpg',
#  'cat.11798.jpg',
#  'cat.2813.jpg',
#  'cat.518.jpg',
#  'cat.2528.jpg',
#  'cat.1237.jpg',
#  'cat.1524.jpg',
#  'cat.5232.jpg',
#  'cat.2948.jpg',
#  'cat.3155.jpg',
#  'cat.1394.jpg',
#  'cat.5323.jpg',
#  'cat.1502.jpg',
#  'cat.612.jpg',
#  'cat.677.jpg',
#  'cat.11361.jpg',
#  'cat.8639.jpg',
#  'cat.9930.jpg',
#  'cat.2055.jpg',
#  'cat.6465.jpg',
#  'cat.2983.jpg',
#  'cat.8290.jpg',
#  'cat.6585.jpg',
#  'cat.2503.jpg',
#  'cat.11464.jpg',
#  'cat.9749.jpg',
#  'cat.8609.jpg',
#  'cat.11333.jpg',
#  'cat.4456.jpg',
#  'cat.9982.jpg',
#  'cat.11794.jpg',
#  'cat.6164.jpg',
#  'cat.1740.jpg',
#  'cat.6808.jpg',
#  'cat.11082.jpg',
#  'cat.6329.jpg',
#  'cat.6330.jpg',
#  'cat.8226.jpg',
#  'cat.6547.jpg',
#  'cat.5372.jpg',
#  'cat.6663.jpg',
#  'cat.6425.jpg',
#  'cat.6391.jpg',
#  'cat.11498.jpg',
#  'cat.35.jpg',
#  'cat.1109.jpg',
#  'cat.9487.jpg',
#  'cat.12081.jpg',
#  'cat.1069.jpg',
#  'cat.4269.jpg',
#  'cat.10809.jpg',
#  'cat.11418.jpg',
#  'cat.7076.jpg',
#  'cat.4981.jpg',
#  'cat.6166.jpg',
#  'cat.8412.jpg',
#  'cat.12295.jpg',
#  'cat.9762.jpg',
#  'cat.2343.jpg',
#  'cat.8985.jpg',
#  'cat.11924.jpg',
#  'cat.4307.jpg',
#  'cat.782.jpg',
#  'cat.6156.jpg',
#  'cat.86.jpg',
#  'cat.10900.jpg',
#  'cat.1930.jpg',
#  'cat.8313.jpg',
#  'cat.2911.jpg',
#  'cat.3783.jpg',
#  'cat.8085.jpg',
#  'cat.10766.jpg',
#  'cat.10328.jpg',
#  'cat.5332.jpg',
#  'cat.9875.jpg',
#  'cat.11558.jpg',
#  'cat.1418.jpg',
#  'cat.11978.jpg',
#  'cat.7578.jpg',
#  'cat.3523.jpg',
#  'cat.3610.jpg',
#  'cat.6426.jpg',
#  'cat.5003.jpg',
#  'cat.9699.jpg',
#  'cat.2386.jpg',
#  'cat.7376.jpg',
#  'cat.4324.jpg',
#  'cat.6612.jpg',
#  'cat.3403.jpg',
#  'cat.10650.jpg',
#  'cat.8117.jpg',
#  'cat.9701.jpg',
#  'cat.9166.jpg',
#  'cat.3964.jpg',
#  'cat.7327.jpg',
#  'cat.11403.jpg',
#  'cat.9928.jpg',
#  'cat.7751.jpg',
#  'cat.8578.jpg',
#  'cat.2566.jpg',
#  'cat.12149.jpg',
#  'cat.1159.jpg',
#  'cat.10880.jpg',
#  'cat.11451.jpg',
#  'cat.3235.jpg',
#  'cat.9836.jpg',
#  'cat.4355.jpg',
#  'cat.6264.jpg',
#  'cat.2288.jpg',
#  'cat.10449.jpg',
#  'cat.12259.jpg',
#  'cat.2030.jpg',
#  'cat.1162.jpg',
#  'cat.11756.jpg',
#  'cat.10382.jpg',
#  'cat.10087.jpg',
#  'cat.8987.jpg',
#  'cat.5604.jpg',
#  'cat.6781.jpg',
#  'cat.2396.jpg',
#  'cat.7380.jpg',
#  'cat.2442.jpg',
#  'cat.1737.jpg',
#  'cat.5555.jpg',
#  'cat.8867.jpg',
#  'cat.5192.jpg',
#  'cat.11462.jpg',
#  'cat.3555.jpg',
#  'cat.2382.jpg',
#  'cat.4569.jpg',
#  'cat.8731.jpg',
#  'cat.1258.jpg',
#  'cat.11550.jpg',
#  'cat.12449.jpg',
#  'cat.3082.jpg',
#  'cat.6617.jpg',
#  'cat.5808.jpg',
#  'cat.1671.jpg',
#  'cat.8086.jpg',
#  'cat.3111.jpg',
#  'cat.473.jpg',
#  'cat.9725.jpg',
#  'cat.6623.jpg',
#  'cat.11650.jpg',
#  'cat.1290.jpg',
#  'cat.8335.jpg',
#  'cat.4816.jpg',
#  'cat.5874.jpg',
#  'cat.3841.jpg',
#  'cat.2746.jpg',
#  'cat.11283.jpg',
#  'cat.6318.jpg',
#  'cat.11032.jpg',
#  'cat.6372.jpg',
#  'cat.6453.jpg',
#  'cat.1261.jpg',
#  'cat.10565.jpg',
#  'cat.11742.jpg',
#  'cat.8685.jpg',
#  'cat.2220.jpg',
#  'cat.8176.jpg',
#  'cat.543.jpg',
#  'cat.5059.jpg',
#  'cat.2615.jpg',
#  'cat.11531.jpg',
#  'cat.5584.jpg',
#  'cat.10188.jpg',
#  'cat.5175.jpg',
#  'cat.10844.jpg',
#  'cat.5504.jpg',
#  'cat.8934.jpg',
#  'cat.3607.jpg',
#  'cat.6741.jpg',
#  'cat.3251.jpg',
#  'cat.7541.jpg',
#  'cat.11912.jpg',
#  'cat.1021.jpg',
#  'cat.4829.jpg',
#  'cat.8700.jpg',
#  'cat.2836.jpg',
#  'cat.338.jpg',
#  'cat.1879.jpg',
#  'cat.6448.jpg',
#  'cat.9028.jpg',
#  'cat.10664.jpg',
#  'cat.11992.jpg',
#  'cat.548.jpg',
#  'cat.6411.jpg',
#  'cat.10813.jpg',
#  'cat.9124.jpg',
#  'cat.8041.jpg',
#  'cat.11271.jpg',
#  'cat.6900.jpg',
#  'cat.3937.jpg',
#  'cat.8500.jpg',
#  'cat.6023.jpg',
#  'cat.5723.jpg',
#  'cat.3073.jpg',
#  'cat.9848.jpg',
#  'cat.4986.jpg',
#  'cat.12035.jpg',
#  'cat.4545.jpg',
#  'cat.2276.jpg',
#  'cat.10197.jpg',
#  'cat.2037.jpg',
#  'cat.2548.jpg',
#  'cat.5651.jpg',
#  'cat.6512.jpg',
#  'cat.6826.jpg',
#  'cat.7202.jpg',
#  'cat.5355.jpg',
#  'cat.3808.jpg',
#  'cat.4281.jpg',
#  'cat.1534.jpg',
#  'cat.4328.jpg',
#  'cat.8653.jpg',
#  'cat.6521.jpg',
#  'cat.9822.jpg',
#  'cat.7642.jpg',
#  'cat.3811.jpg',
#  'cat.8152.jpg',
#  'cat.3775.jpg',
#  'cat.4131.jpg',
#  'cat.2960.jpg',
#  'cat.4922.jpg',
#  'cat.5254.jpg',
#  'cat.11281.jpg',
#  'cat.2018.jpg',
#  'cat.4938.jpg',
#  'cat.3742.jpg',
#  'cat.10967.jpg',
#  'cat.1417.jpg',
#  'cat.6709.jpg',
#  'cat.1173.jpg',
#  'cat.6788.jpg',
#  'cat.6926.jpg',
#  'cat.5034.jpg',
#  'cat.8869.jpg',
#  'cat.10616.jpg',
#  'cat.5303.jpg',
#  'cat.9026.jpg',
#  'cat.12465.jpg',
#  'cat.2177.jpg',
#  'cat.6698.jpg',
#  'cat.2807.jpg',
#  'cat.7676.jpg',
#  'cat.9357.jpg',
#  'cat.9632.jpg',
#  'cat.2679.jpg',
#  'cat.3565.jpg',
#  'cat.7837.jpg',
#  'cat.11042.jpg',
#  'cat.11942.jpg',
#  'cat.10140.jpg',
#  'cat.444.jpg',
#  'cat.3983.jpg',
#  'cat.6065.jpg',
#  'cat.9162.jpg',
#  'cat.12132.jpg',
#  'cat.3420.jpg',
#  'cat.3229.jpg',
#  'cat.2264.jpg',
#  'cat.12417.jpg',
#  'cat.4143.jpg',
#  'cat.5601.jpg',
#  'cat.7763.jpg',
#  'cat.5685.jpg',
#  'cat.9266.jpg',
#  'cat.2346.jpg',
#  'cat.2495.jpg',
#  'cat.4354.jpg',
#  'cat.6148.jpg',
#  'cat.1111.jpg',
#  'cat.1043.jpg',
#  'cat.5361.jpg',
#  ...]

# %%
len(os.listdir(train_path+'cat')), len(os.listdir(train_path+'dog'))
# Out:
# (12500, 5026)

# %%
len(os.listdir(val_path+'cat')), len(os.listdir(val_path+'dog'))
# Out:
# (1219, 1071)

# %%
# Walk through cell_images directory and list number of files
for dirpath, dirnames, filenames in os.walk(my_data_dir):
  print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'data'.
# There are 2 directories and 0 images in 'data/train'.
# There are 0 directories and 5026 images in 'data/train/dog'.
# There are 0 directories and 12500 images in 'data/train/cat'.
# There are 0 directories and 6897 images in 'data/test'.
# There are 2 directories and 0 images in 'data/validation'.
# There are 0 directories and 1071 images in 'data/validation/dog'.
# There are 0 directories and 1219 images in 'data/validation/cat'.

# %% [markdown]
# **Let's take an example images from both train-cat and train-dog folders to observe process**

# %%
os.listdir(train_path+'cat')[0:10]
# Out:
# ['cat.1434.jpg',
#  'cat.7828.jpg',
#  'cat.3710.jpg',
#  'cat.11175.jpg',
#  'cat.866.jpg',
#  'cat.6376.jpg',
#  'cat.7308.jpg',
#  'cat.11219.jpg',
#  'cat.5125.jpg',
#  'cat.5298.jpg']

# %%
os.listdir(train_path+'cat')[0]
# Out:
# 'cat.1434.jpg'

# %%
os.listdir(train_path+'dog')[0]
# Out:
# 'dog.3106.jpg'

# %%
path1=train_path+'cat'+'/cat.4593.jpg'
path2=train_path+'dog'+'/dog.10086.jpg'

# %%
imread(path1)
# Out:
# array([[[117, 119, 108],
#         [123, 125, 114],
#         [110, 111, 103],
#         ...,
#         [145, 153, 140],
#         [133, 144, 128],
#         [129, 137, 124]],
#
#        [[118, 120, 109],
#         [124, 126, 115],
#         [111, 112, 104],
#         ...,
#         [134, 142, 129],
#         [129, 137, 122],
#         [131, 139, 124]],
#
#        [[119, 121, 110],
#         [125, 127, 116],
#         [113, 114, 106],
#         ...,
#         [124, 130, 116],
#         [126, 133, 117],
#         [132, 140, 119]],
#
#        ...,
#
#        [[ 61,  57,  54],
#         [  7,   3,   0],
#         [ 17,  12,   9],
#         ...,
#         [144, 144, 144],
#         [154, 154, 154],
#         [152, 152, 152]],
#
#        [[ 81,  77,  74],
#         [ 20,  16,  13],
#         [ 20,  15,  12],
#         ...,
#         [145, 145, 145],
#         [154, 154, 154],
#         [153, 151, 152]],
#
#        [[ 99,  95,  92],
#         [ 30,  26,  23],
#         [ 20,  15,  12],
#         ...,
#         [145, 145, 145],
#         [154, 154, 154],
#         [153, 151, 152]]], dtype=uint8)

# %%
cat_img=imread(path1)
dog_img=imread(path2)

# %%
plt.imshow(cat_img);

# %%
plt.imshow(dog_img);

# %%
# View an image
import random

def view_random_image(target_dir, target_class):
  # Setup target directory (we'll view images from here)
  target_folder = target_dir+target_class

  # Get a random image path
  random_image = random.sample(os.listdir(target_folder), 1)

  # Read in the image and plot it using matplotlib
  img = imread(target_folder + "/" + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis("off");

  print(f"Image shape: {img.shape}") # show the shape of the image

  return img

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_path,
                        target_class="cat")
# Out:
# Image shape: (175, 174, 3)

# %%
# View a random image from the training dataset
img = view_random_image(target_dir=train_path,
                        target_class="dog")
# Out:
# Image shape: (217, 249, 3)

# %%
# View a random image from the training dataset  (if we dont assign an image variable, it shows array info too!)
import random
view_random_image(target_dir=train_path,
                        target_class=random.choice(class_names)) # get a random class name
# Out:
# Image shape: (321, 479, 3)
# array([[[217, 217, 219],
#         [217, 217, 219],
#         [217, 217, 219],
#         ...,
#         [ 71,  48,  32],
#         [ 80,  54,  39],
#         [ 83,  57,  42]],
#
#        [[217, 217, 219],
#         [217, 217, 219],
#         [217, 217, 219],
#         ...,
#         [ 71,  48,  32],
#         [ 80,  54,  39],
#         [ 83,  57,  42]],
#
#        [[217, 217, 219],
#         [217, 217, 219],
#         [217, 217, 219],
#         ...,
#         [ 71,  48,  32],
#         [ 80,  54,  39],
#         [ 83,  57,  42]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [252, 248, 245],
#         [251, 247, 244],
#         [251, 247, 244]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [252, 248, 245],
#         [251, 247, 244],
#         [251, 247, 244]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [251, 250, 248],
#         [251, 250, 248],
#         [250, 249, 247]]], dtype=uint8)

# %%
# View a random image from the training dataset 
import random
img = view_random_image(target_dir=train_path,
                        target_class=random.choice(class_names)) # get a random class name
# Out:
# Image shape: (149, 200, 3)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Defining Input Shape

# %% [markdown]
# **Let's decide on the final dimension of these images.**

# %%
cat_img.shape
# Out:
# (379, 417, 3)

# %%
dog_img.shape
# Out:
# (299, 300, 3)

# %%
# Alternative way

# x = []

# y = []

# for image in os.listdir(train_path+'/cat'):

#     img = imread(train_path+'/cat/'+image)

#     d1,d2,_ = img.shape

#     x.append(d1)

#     y.append(d2)

# %%
x = [imread(train_path+'cat/'+image).shape[0] for image in os.listdir(train_path+'cat')]
y = [imread(train_path+'cat/'+image).shape[1] for image in os.listdir(train_path+'cat')]

# %%
sns.scatterplot(x,y);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
np.mean(x), np.median(x)
# Out:
# (356.46712, 374.0)

# %%
np.mean(y), np.median(y)
# Out:
# (410.52264, 470.0)

# %%
image_shape = (128,128,3)

# %% [markdown]
# ## Scalling

# %% [markdown]
# **Let's check the images if they are needed to be scaled or not**

# %%
cat_img.max()
# Out:
# 255

# %%
cat_img.min()
# Out:
# 0

# %% [markdown]
# As we see above, images need to be scaled

# %% [markdown]
# ## Image Data Generator

# %% [markdown]
# **Image Manipulation**
#
# We can use the ImageDataGenerator to manipulate the images with rotation, resizing, and scaling so the model becomes more robust to different images that our data set doesn't have. ImageDataGenerator does the followings.
#
# * Accepts a batch of images used for training.
# * Applies a series of random transformations to each image in the batch.
# * Replaces the original batch with randomly transformed batch.
# * Training the CNN on this randomly transformed batch.
#
# The goal of applying data augmentation is to have a more generalized model.
#
# Data augmentation is a way to try and prevent a model overfitting. If your model is overfiting (e.g. the validation loss keeps increasing), you may want to try using data augmentation.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# help(ImageDataGenerator)

# %%
image_gen = ImageDataGenerator(rotation_range=15, # rotate the image 15 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 10%
                               height_shift_range=0.10, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allow horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(dog_img);

# %%
plt.imshow(image_gen.random_transform(dog_img));

# %% [markdown]
# ### Taking the path to a directory & Generating batches of augmented data
#
# flow_from_directory function works with images organized in sub-directories. Our directories should include only one class of images, so one folder per class of images.

# %%
#help(image_gen.flow_from_directory)
#Takes the path to a directory & generates batches of augmented data.

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(val_path)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 0 images belonging to 0 classes.

# %%
batch_size = 32

# %%
train_image_gen = image_gen.flow_from_directory(directory=train_path,
                                                target_size=image_shape[:2],
                                                color_mode='rgb',
                                                batch_size=batch_size,
                                                class_mode='binary',
                                                shuffle=True)
# Out:
# Found 17526 images belonging to 2 classes.

# %%
val_image_gen = image_gen.flow_from_directory(directory=val_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=False)
# Out:
# Found 2290 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
train_image_gen[0][0].shape
# Out:
# (32, 128, 128, 3)

# %%
len(train_image_gen), len(val_image_gen)
# Out:
# (548, 72)

# %%
len(train_image_gen)*batch_size, len(val_image_gen)*batch_size
# Out:
# (17536, 2304)

# %%
# Get a sample of the training data batch 
images, labels = train_image_gen.next() # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %%
# Get a sample of the testing data batch 
images, labels = val_image_gen.next() # get the 'next' batch of images/labels
len(images), len(labels)
# Out:
# (32, 32)

# %% [markdown]
# # Modelling-1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
model1 = Sequential()

model1.add(Conv2D(filters=16, kernel_size=(3,3),input_shape=image_shape, activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())

model1.add(Dense(128))
model1.add(Activation('relu'))

model1.add(Dense(64))
model1.add(Activation('relu'))

model1.add(Dense(1))
model1.add(Activation('sigmoid'))

model1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  activation (Activation)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 695,713
# Trainable params: 695,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights = True)

# %%
model1.fit(train_image_gen,
          epochs=10,
          steps_per_epoch=len(train_image_gen),
          validation_data=val_image_gen,
          validation_steps=len(val_image_gen),
          callbacks=[early_stop])
# Out:
# Epoch 1/10
# 548/548 [==============================] - 126s 207ms/step - loss: 0.5821 - accuracy: 0.7137 - val_loss: 0.7078 - val_accuracy: 0.5838
# Epoch 2/10
# 548/548 [==============================] - 110s 201ms/step - loss: 0.5085 - accuracy: 0.7589 - val_loss: 0.5635 - val_accuracy: 0.7218
# Epoch 3/10
# 548/548 [==============================] - 112s 204ms/step - loss: 0.4623 - accuracy: 0.7842 - val_loss: 0.5534 - val_accuracy: 0.7345
# Epoch 4/10
# 548/548 [==============================] - 110s 202ms/step - loss: 0.4157 - accuracy: 0.8102 - val_loss: 0.5149 - val_accuracy: 0.7533
# Epoch 5/10
# 548/548 [==============================] - 110s 201ms/step - loss: 0.3914 - accuracy: 0.8239 - val_loss: 0.4676 - val_accuracy: 0.7852
# Epoch 6/10
# 548/548 [==============================] - 112s 205ms/step - loss: 0.3694 - accuracy: 0.8346 - val_loss: 0.4696 - val_accuracy: 0.7843
# Epoch 7/10
# 548/548 [==============================] - 110s 201ms/step - loss: 0.3430 - accuracy: 0.8493 - val_loss: 0.4375 - val_accuracy: 0.8096
# Epoch 8/10
# 548/548 [==============================] - 111s 203ms/step - loss: 0.3142 - accuracy: 0.8632 - val_loss: 0.4227 - val_accuracy: 0.8323
# Epoch 9/10
# 548/548 [==============================] - 110s 200ms/step - loss: 0.3020 - accuracy: 0.8720 - val_loss: 0.3835 - val_accuracy: 0.8266
# Epoch 10/10
# 548/548 [==============================] - 111s 203ms/step - loss: 0.2848 - accuracy: 0.8766 - val_loss: 0.4381 - val_accuracy: 0.7991

# %%
summary = pd.DataFrame(model1.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # Modelling-2

# %%
model2 = Sequential()

model2.add(Conv2D(filters=16, kernel_size=(3,3),input_shape=image_shape, activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Flatten())

model2.add(Dense(128))
model2.add(Activation('relu'))

model2.add(Dense(128))
model2.add(Activation('relu'))

model2.add(Dense(1))
model2.add(Activation('sigmoid'))

model2.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 126, 126, 16)      448
#
#  batch_normalization (BatchN  (None, 126, 126, 16)     64
#  ormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 63, 63, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 61, 61, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 61, 61, 32)       128
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_3 (Dense)             (None, 128)               589952
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_5 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 704,993
# Trainable params: 704,513
# Non-trainable params: 480
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights = True)

# %%
model2.fit(train_image_gen,
          epochs=15,
          steps_per_epoch=len(train_image_gen),
          validation_data=val_image_gen,
          validation_steps=len(val_image_gen),
          callbacks=[early_stop])
# Out:
# Epoch 1/15
# 548/548 [==============================] - 113s 205ms/step - loss: 0.5399 - accuracy: 0.7471 - val_loss: 0.8469 - val_accuracy: 0.5913
# Epoch 2/15
# 548/548 [==============================] - 113s 205ms/step - loss: 0.4398 - accuracy: 0.7996 - val_loss: 0.4959 - val_accuracy: 0.7707
# Epoch 3/15
# 548/548 [==============================] - 111s 202ms/step - loss: 0.3810 - accuracy: 0.8296 - val_loss: 0.4818 - val_accuracy: 0.7852
# Epoch 4/15
# 548/548 [==============================] - 111s 202ms/step - loss: 0.3383 - accuracy: 0.8510 - val_loss: 0.9209 - val_accuracy: 0.6616
# Epoch 5/15
# 548/548 [==============================] - 112s 205ms/step - loss: 0.3045 - accuracy: 0.8675 - val_loss: 0.3669 - val_accuracy: 0.8389
# Epoch 6/15
# 548/548 [==============================] - 110s 201ms/step - loss: 0.2799 - accuracy: 0.8776 - val_loss: 1.5296 - val_accuracy: 0.5838
# Epoch 7/15
# 548/548 [==============================] - 112s 204ms/step - loss: 0.2586 - accuracy: 0.8906 - val_loss: 0.5966 - val_accuracy: 0.7559
# Epoch 8/15
# 548/548 [==============================] - 111s 202ms/step - loss: 0.2325 - accuracy: 0.9016 - val_loss: 0.4426 - val_accuracy: 0.8192

# %%
summary = pd.DataFrame(model2.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # Modelling-3

# %%
model3 = Sequential()

model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', input_shape=image_shape, activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))

model3.add(Flatten())

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(128))
model3.add(Activation('relu'))

model3.add(Dense(1))
model3.add(Activation('sigmoid'))

model3.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 128, 128, 16)      448
#
#  batch_normalization_12 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 16)      2320
#
#  batch_normalization_13 (Bat  (None, 128, 128, 16)     64
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 32)        4640
#
#  batch_normalization_14 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 32)        9248
#
#  batch_normalization_15 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 64)        18496
#
#  batch_normalization_16 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_17 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_18 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 128)       147584
#
#  batch_normalization_19 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 8192)              0
#
#  dense_9 (Dense)             (None, 128)               1048704
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  activation_10 (Activation)  (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
#  activation_11 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 1,360,785
# Trainable params: 1,359,825
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights = True)

# %% [markdown]
# #### IF YOU WANT, YOU CAN ADD class_weight parameter into the model.fit to make the model better but it is not certain that it will work. There are two alternatives to use the class_weight

# %%
# ALTERNATIVE 1

# y_train=train_image_gen.classes
# y_train

# counts = np.bincount(y_train)
# print(
   # "Number of positive samples in training data: {} ({:.2f}% of total)".format(
        # counts[1], 100 * float(counts[1]) / len(y_train)
   #  )
# )
# weight_for_0 = 1.0 / counts[0]
# weight_for_1 = 1.0 / counts[1]

# class_weight = {0: weight_for_0, 1: weight_for_1}

# %%
# ALTERNATIVE 2 (skilearn)
# class_weights = class_weight.compute_class_weight(
#            'balanced',
#             classes = np.unique(train_image_gen.classes), 
#             y=train_image_gen.classes)

# class_weights = dict(enumerate(class_weights))
# model1.fit(train_image_gen,
#           epochs=20,
#           steps_per_epoch=len(train_image_gen),
#           validation_data=val_image_gen,
#           validation_steps=len(val_image_gen),
#           callbacks=[early_stop],
#           class_weight=class_weights)

# %%
model3.fit(train_image_gen,
          epochs=20,
          steps_per_epoch=len(train_image_gen),
          validation_data=val_image_gen,
          validation_steps=len(val_image_gen),
          callbacks=[early_stop])
# Out:
# Epoch 1/20
# 548/548 [==============================] - 121s 217ms/step - loss: 0.5952 - accuracy: 0.7287 - val_loss: 0.7164 - val_accuracy: 0.5546
# Epoch 2/20
# 548/548 [==============================] - 117s 214ms/step - loss: 0.4827 - accuracy: 0.7767 - val_loss: 0.7351 - val_accuracy: 0.6769
# Epoch 3/20
# 548/548 [==============================] - 116s 212ms/step - loss: 0.4176 - accuracy: 0.8077 - val_loss: 0.4957 - val_accuracy: 0.7485
# Epoch 4/20
# 548/548 [==============================] - 118s 215ms/step - loss: 0.3548 - accuracy: 0.8430 - val_loss: 0.4765 - val_accuracy: 0.7817
# Epoch 5/20
# 548/548 [==============================] - 116s 211ms/step - loss: 0.2910 - accuracy: 0.8775 - val_loss: 0.4888 - val_accuracy: 0.8197
# Epoch 6/20
# 548/548 [==============================] - 117s 214ms/step - loss: 0.2508 - accuracy: 0.8952 - val_loss: 0.3661 - val_accuracy: 0.8476
# Epoch 7/20
# 548/548 [==============================] - 116s 211ms/step - loss: 0.2189 - accuracy: 0.9101 - val_loss: 0.4837 - val_accuracy: 0.7974
# Epoch 8/20
# 548/548 [==============================] - 118s 215ms/step - loss: 0.2016 - accuracy: 0.9173 - val_loss: 0.3883 - val_accuracy: 0.8476
# Epoch 9/20
# 548/548 [==============================] - 118s 214ms/step - loss: 0.1867 - accuracy: 0.9226 - val_loss: 0.3773 - val_accuracy: 0.8581

# %%
summary = pd.DataFrame(model3.history.history)

# %%
summary[["loss", "val_loss"]].plot();

# %%
summary[["accuracy", "val_accuracy"]].plot();

# %% [markdown]
# # Evaluation on Test Data

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
score = model3.evaluate(val_image_gen)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 72/72 [==============================] - 13s 176ms/step - loss: 0.3648 - accuracy: 0.8524
# Test loss: 0.36481595039367676
# Test accuracy: 0.8524017333984375

# %%
pred_prob = model3.predict(val_image_gen)
pred_prob
# Out:
# array([[6.4857997e-04],
#        [8.7978825e-02],
#        [1.0131162e-02],
#        ...,
#        [9.0693057e-01],
#        [9.9038130e-01],
#        [9.7582698e-01]], dtype=float32)

# %%
y_pred = pred_prob > 0.5
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
y_test = val_image_gen.classes

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.95      0.87      1219
#            1       0.93      0.74      0.82      1071
#
#     accuracy                           0.85      2290
#    macro avg       0.87      0.84      0.85      2290
# weighted avg       0.86      0.85      0.85      2290

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1157,   62],
#        [ 278,  793]])

# %%
model3.save('cat_dog_detector.h5')

# %% [markdown]
# # Prediction-1

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
model=load_model('cat_dog_detector.h5')

# %%
img_path = "/content/data/test/10005.jpg"

# %%
img=image.load_img(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=249x227 at 0x7F24A87D67D0>

# %%
img = np.array(img)

# %%
img.shape
# Out:
# (227, 249, 3)

# %%
resized_img = image.smart_resize(img, (128, 128)) # img has to be numpy array 
resized_img.shape

#resized_img = img.resize((128, 128)) # img has to be image format (like jpg, png etc)
#resized_img
# Out:
# (128, 128, 3)

# %%
resized_img.max()
# Out:
# 254.4644

# %%
resized_img = resized_img / 255

# %%
plt.imshow(resized_img)

# %%
resized_img=np.expand_dims(resized_img, axis=0)
resized_img.shape
# Out:
# (1, 128, 128, 3)

# %%
model.predict(resized_img)
# Out:
# array([[0.01896358]], dtype=float32)

# %%
val_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# # Prediction-2

# %%
random_image = random.sample(os.listdir(test_path), 1)
random_image
# Out:
# ['4402.jpg']

# %%
image_path = test_path + "/" + random_image[0]
image_path
# Out:
# 'data/test//4402.jpg'

# %%
my_image = image.load_img(image_path, target_size=image_shape)

# %%
my_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F24A8532110>

# %%
type(my_image)
# Out:
# PIL.Image.Image

# %%
#my_image = np.array(my_image)
my_image = image.img_to_array(my_image)

# %%
my_image.max()
# Out:
# 174.0

# %%
my_image = my_image / 255

# %%
my_image.shape
# Out:
# (128, 128, 3)

# %%
my_image = np.expand_dims(my_image, axis=0)

# %%
my_image.shape
# Out:
# (1, 128, 128, 3)

# %%
model.predict(my_image)
# Out:
# array([[0.04832282]], dtype=float32)

# %%
train_image_gen.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
def pred_and_plot(model, img_size):
    """
    Imports an image located at filename, makes a prediction on it with
    a trained model and plots the image with the predicted class as the title.
    """
    # Import the target image and preprocess it
    random_image = random.sample(os.listdir(test_path), 1)
    img_path = test_path + "/" + random_image[0]
    img = image.load_img(img_path, target_size=img_size)
    img = np.array(img)
    if img.max() > 1:
        img = img/255
  
    # Make a prediction
    pred = model.predict(np.expand_dims(img, axis=0))
    print("prediction_probability: ", pred.max())

    # Get the predicted class
    if len(pred[0]) > 1: # check for multi-class
        pred_class = class_names[pred.argmax()] # if more than one output, take the max
    else:
        pred_class = class_names[int(tf.round(pred)[0][0])] # if only one output, round

    # Plot the image and predicted class
    plt.imshow(img)
    plt.title(f"Prediction: {pred_class}")
    plt.axis(False);

# %%
pred_and_plot(model, image_shape[:2])
# Out:
# prediction_probability:  0.011262042
