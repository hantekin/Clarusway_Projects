# %% [markdown]
# <h1 style="text-align: center;">ANN<br>Churn Prediction for Bank Customer<br><h1>

# %% [markdown]
# We have a dataset with details of a bank's customers, and the target variable is a binary variable that reflects whether the customer has left the bank (closed his/her account) or remains a customer.
#
# The features in the given dataset are:
# - **rownumber:** Row Numbers from 1 to 10000.
# - **customerid:** A unique ID that identifies each customer.
# - **surname:** The customer’s surname.
# - **creditscore:** A credit score is a number between 300–850 that depicts a consumer's creditworthiness.
# - **geography:** The country from which the customer belongs to.
# - **Gender:** The customer’s gender: Male, Female
# - **Age:** The customer’s current age, in years, at the time of being customer.
# - **tenure:** The number of years for which the customer has been with the bank.
# - **balance:** Bank balance of the customer.
# - **numofproducts:** the number of bank products the customer is utilising.
# - **hascrcard:** The number of credit cards given to the customer by the bank.
# - **isactivemember:** Binary Flag for indicating if the client is active or not with the bank before the moment where the client exits the company (recorded in the variable "exited")
# - **exited:** Binary flag 1 if the customer closed account with bank and 0 if the customer is retained.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Import  libraries & data

# %%
# tfcpu envoirement used

# %%
# Importing the libraries for EDA
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
# Importing libraries for DL and ML
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from livelossplot import PlotLossesKerasTF #

# %%
df = pd.read_csv("Churn_Modelling.csv", index_col='RowNumber')
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1              0.000              1          1               1
# 2          83807.860              1          0               1
# 3         159660.800              3          1               0
# 4              0.000              2          0               0
# 5         125510.820              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1               101348.880       1
# 2               112542.580       0
# 3               113931.570       1
# 4                93826.630       0
# 5                79084.100       0

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum().any() # No missing values
# Out:
# False

# %%
df.duplicated().sum() # No duplicates
# Out:
# 0

# %%
df.describe().T # summary statistics
# Out:
#                     count         mean       std          min          25%  \
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
# pip install sweetviz

# %%
import sweetviz # for visualizing the data

my_report = sweetviz.analyze([df, "original data"],target_feat='Exited')

my_report.show_notebook(layout="vertical", w ="980", h= 700, scale= .8)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="980" height="700" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %%
df.Balance.plot(kind="box",vert=False)
# Out:
# <AxesSubplot:>

# %%
df.drop(['CustomerId', 'Surname'], axis=1, inplace=True)

# %%
print(df.Exited.value_counts())
sns.countplot(df["Exited"]);
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df.hist(figsize=(15, 12), bins=15, xrot=90);
plt.tight_layout()

# %%
cat_list = ["Gender", "HasCrCard", "IsActiveMember", "Geography"]
index = 0
plt.figure(figsize=(16, 12))
for i in cat_list:
    index += 1
    plt.subplot(2, 2, index)
    sns.countplot(data=df, x=i, hue="Exited")

# %%
df.groupby("Age")["Exited"].value_counts()
# Out:
# Age  Exited
# 18   0         20
#      1          2
# 19   0         26
#      1          1
# 20   0         38
#                ..
# 84   0          1
#      1          1
# 85   0          1
# 88   0          1
# 92   0          2
# Name: Exited, Length: 128, dtype: int64

# %%
plt.figure(figsize=(20, 7))
sns.countplot(df.Age, hue=df.Exited);

# %%
df.CreditScore.describe()
# Out:
# count   10000.000
# mean      650.529
# std        96.653
# min       350.000
# 25%       584.000
# 50%       652.000
# 75%       718.000
# max       850.000
# Name: CreditScore, dtype: float64

# %%
def credit_transformer(x, y):
    """to produce a new value by using credit score and has credit card"""

    if x < 350 and y == 0:
        return 0
    if x < 350 and y > 0:
        return 1
    if x < 718 and y == 0:
        return 2
    if x < 718 and y > 0:
        return 3
    else:
        return 4

# %%
customer_value = [credit_transformer(x, y) for x, y in zip(df.CreditScore, df.HasCrCard)]
customer_value[:10]
# Out:
# [3, 2, 3, 2, 4, 3, 4, 3, 2, 3]

# %%
df.insert(10, "customer_value", customer_value)

# %%
df.customer_value
# Out:
# RowNumber
# 1        3
# 2        2
# 3        3
# 4        2
# 5        4
#         ..
# 9996     4
# 9997     3
# 9998     2
# 9999     4
# 10000    4
# Name: customer_value, Length: 10000, dtype: int64

# %% [markdown]
# ----

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), annot=True, cmap='viridis',vmin= -1,vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.corr()['Exited'][:-1].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing of Data

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#            CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619   42       2      0.000              1          1
# 2                  608   41       1  83807.860              1          0
# 3                  502   42       8 159660.800              3          1
# 4                  699   39       1      0.000              2          0
# 5                  850   43       2 125510.820              1          1
#
#            IsActiveMember  EstimatedSalary  customer_value  Exited  \
# RowNumber
# 1                       1       101348.880               3       1
# 2                       1       112542.580               2       0
# 3                       0       113931.570               3       1
# 4                       0        93826.630               2       0
# 5                       1        79084.100               4       0
#
#            Geography_Germany  Geography_Spain  Gender_Male
# RowNumber
# 1                          0                0            0
# 2                          0                1            0
# 3                          0                0            0
# 4                          0                0            0
# 5                          0                1            0

# %%
X = df.drop('Exited', axis=1)
y = df['Exited'].values

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=42)

# %%
scaler = MinMaxScaler() # Minmax scaler mostly used for deep learning as a rule of thumb

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Modelling & Model Performance

# %% [markdown]
# <span class="mark">How many hidden layers should I use? : http://www.faqs.org/faqs/ai-faq/neural-nets/part3/section-9.html (mirror: http://francky.me/aifaq/FAQ-comp.ai.neural-net.pdf)
# How many hidden units should I use? : http://www.faqs.org/faqs/ai-faq/neural-nets/part3/section-10.html (mirror: http://francky.me/aifaq/FAQ-comp.ai.neural-net.pdf)
# What is genetic algorithm? : https://www.researchgate.net/post/What_is_genetic_algorithm1
# Genetic algorithm + neural networks: http://francky.me/doc/mrf2011-HEC-ISIR-ENS_en.pdf (chapter 2.2)</span>

# %% [markdown]
# ### without class_weigth

# %%
tf.random.set_seed(42) # for reproducibility

model = Sequential() # instantiate the model

model.add(Dense(16, activation="relu")) # add the input layer and the first hidden layer
model.add(Dense(8, activation="relu"))  # add the second hidden layer
model.add(Dense(1, activation="sigmoid")) # add the output layer

opt = Adam(lr=0.001) # optimizer 
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"]) # loss function and metrics

# %% [markdown]
# <span class="burk">The patience is often set somewhere between 10 and 100 (10 or 20 is more common), but it really depends on your dataset and network.</span>

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=11,
                           restore_best_weights = True)

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop,PlotLossesKerasTF()])
# Out:
# Loss
# 	training         	 (min:    0.343, max:    0.546, cur:    0.343)
# 	validation       	 (min:    0.302, max:    0.496, cur:    0.302)
# recall
# 	training         	 (min:    0.000, max:    0.456, cur:    0.446)
# 	validation       	 (min:    0.000, max:    0.624, cur:    0.547)
# 64/64 [==============================] - 1s 16ms/step - loss: 0.3432 - recall: 0.4455 - val_loss: 0.3022 - val_recall: 0.5470
# Epoch 97: early stopping

# %%
model.summary() # summary of the model, how many layers, how many nodes in each layer
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                208
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 353
# Trainable params: 353
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history) # loss function history for each epoch
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32") # to convert the probabilities into binary values
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# [[766  30]
#  [110  94]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92       796
#            1       0.76      0.46      0.57       204
#
#     accuracy                           0.86      1000
#    macro avg       0.82      0.71      0.74      1000
# weighted avg       0.85      0.86      0.85      1000

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 32/32 [==============================] - 0s 4ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6848128974361153

# %% [markdown]
# ### with class_weigth

# %%
tf.random.set_seed(42)

model = Sequential()

model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

opt = Adam(lr=0.001)
model.compile(optimizer=opt, 
              loss="binary_crossentropy",
              metrics=["Recall"])

# %%
early_stop = EarlyStopping(monitor="val_loss",
                           mode="auto",
                           verbose=1,
                           patience=10,
                           restore_best_weights = True)

# %%
from sklearn.utils import class_weight

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes=np.unique(y_train),
                                                  y=y_train)

class_weights = {0: class_weights[0], 1: class_weights[1]}
class_weights
# Out:
# {0: 0.6278777731268314, 1: 2.454991816693944}

# %%
model.fit(x=X_train,
          y=y_train,
          validation_split=.1,
          batch_size=128,
          epochs=200,
          verbose=1,
          callbacks=[early_stop,PlotLossesKerasTF()],
          class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.480, max:    0.684, cur:    0.480)
# 	validation       	 (min:    0.413, max:    0.660, cur:    0.516)
# recall
# 	training         	 (min:    0.342, max:    0.768, cur:    0.749)
# 	validation       	 (min:    0.630, max:    0.867, cur:    0.867)
# 64/64 [==============================] - 1s 17ms/step - loss: 0.4798 - recall: 0.7494 - val_loss: 0.5159 - val_recall: 0.8674
# Epoch 52: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 3ms/step
# [[636 160]
#  [ 57 147]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.85       796
#            1       0.48      0.72      0.58       204
#
#     accuracy                           0.78      1000
#    macro avg       0.70      0.76      0.71      1000
# weighted avg       0.83      0.78      0.80      1000

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for model

# %%
y_pred_proba = model.predict(X_test)
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 32/32 [==============================] - 0s 3ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6460282602275164

# %% [markdown]
# ## GridSearchCV

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier # to use the model in sklearn
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam  # optimizers for gradient descent to use in backpropagation

# %%
def build_classifier(optimizer,learn_rate): # function to build the model
    tf.random.set_seed(42)
    classifier = Sequential()
    classifier.add(Dense(units=16, activation='relu'))
    classifier.add(Dense(units=8, activation='relu'))
    classifier.add(Dense(units=1, activation='sigmoid'))
    classifier.compile(optimizer=optimizer(learn_rate),
                       loss='binary_crossentropy',
                       metrics=['Recall'])
    return classifier

# %%
class_weights
# Out:
# {0: 0.6278777731268314, 1: 2.454991816693944}

# %%
classifier = KerasClassifier(build_fn=build_classifier, validation_split = 0.1, epochs=150) # instantiate the classifier
parameters = {
    'batch_size': [128, 256],
    'optimizer': [Adam, RMSprop, Adadelta, Nadam],
    'learn_rate': [0.001, 0.003]
} # parameters to tune
grid_model = GridSearchCV(estimator=classifier,
                          param_grid=parameters,
                          scoring='recall',
                          cv=5,
                          n_jobs=-1,
                          verbose=0).fit(X_train,
                                         y_train,
                                         class_weight=class_weights) # grid search to find the best parameters
# Out:
# Epoch 1/150
# 64/64 [==============================] - 3s 13ms/step - loss: 0.6674 - recall: 0.5593 - val_loss: 0.6126 - val_recall: 0.6685
# Epoch 2/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.6263 - recall: 0.6404 - val_loss: 0.6145 - val_recall: 0.7680
# Epoch 3/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.6011 - recall: 0.6810 - val_loss: 0.5666 - val_recall: 0.7182
# Epoch 4/150
# 64/64 [==============================] - 0s 7ms/step - loss: 0.5806 - recall: 0.7010 - val_loss: 0.5701 - val_recall: 0.7680
# Epoch 5/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5668 - recall: 0.7155 - val_loss: 0.4974 - val_recall: 0.7017
# Epoch 6/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5519 - recall: 0.7100 - val_loss: 0.4610 - val_recall: 0.6740
# Epoch 7/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.5396 - recall: 0.7331 - val_loss: 0.4879 - val_recall: 0.7624
# Epoch 8/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5315 - recall: 0.7258 - val_loss: 0.5244 - val_recall: 0.8508
# Epoch 9/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5203 - recall: 0.7494 - val_loss: 0.5025 - val_recall: 0.8398
# Epoch 10/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5157 - recall: 0.7458 - val_loss: 0.4320 - val_recall: 0.7790
# Epoch 11/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5067 - recall: 0.7530 - val_loss: 0.5137 - val_recall: 0.8508
# Epoch 12/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.5062 - recall: 0.7482 - val_loss: 0.4777 - val_recall: 0.8177
# Epoch 13/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4982 - recall: 0.7597 - val_loss: 0.5634 - val_recall: 0.8785
# Epoch 14/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4969 - recall: 0.7603 - val_loss: 0.4493 - val_recall: 0.8177
# Epoch 15/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4925 - recall: 0.7615 - val_loss: 0.4404 - val_recall: 0.8122
# Epoch 16/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4896 - recall: 0.7579 - val_loss: 0.4785 - val_recall: 0.8398
# Epoch 17/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4862 - recall: 0.7597 - val_loss: 0.4402 - val_recall: 0.8232
# Epoch 18/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4836 - recall: 0.7676 - val_loss: 0.4457 - val_recall: 0.8232
# Epoch 19/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4838 - recall: 0.7615 - val_loss: 0.4680 - val_recall: 0.8287
# Epoch 20/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4838 - recall: 0.7694 - val_loss: 0.3970 - val_recall: 0.8066
# Epoch 21/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4808 - recall: 0.7597 - val_loss: 0.4303 - val_recall: 0.8232
# Epoch 22/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4786 - recall: 0.7639 - val_loss: 0.4537 - val_recall: 0.8343
# Epoch 23/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4767 - recall: 0.7633 - val_loss: 0.3987 - val_recall: 0.8177
# Epoch 24/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4833 - recall: 0.7561 - val_loss: 0.4792 - val_recall: 0.8453
# Epoch 25/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4742 - recall: 0.7760 - val_loss: 0.4175 - val_recall: 0.8122
# Epoch 26/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4732 - recall: 0.7621 - val_loss: 0.4469 - val_recall: 0.8398
# Epoch 27/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4729 - recall: 0.7657 - val_loss: 0.5055 - val_recall: 0.8729
# Epoch 28/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4803 - recall: 0.7688 - val_loss: 0.5164 - val_recall: 0.8619
# Epoch 29/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4730 - recall: 0.7645 - val_loss: 0.5140 - val_recall: 0.8729
# Epoch 30/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4679 - recall: 0.7760 - val_loss: 0.4850 - val_recall: 0.8564
# Epoch 31/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4706 - recall: 0.7682 - val_loss: 0.4177 - val_recall: 0.8177
# Epoch 32/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4681 - recall: 0.7651 - val_loss: 0.4498 - val_recall: 0.8398
# Epoch 33/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4661 - recall: 0.7700 - val_loss: 0.3741 - val_recall: 0.7680
# Epoch 34/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4671 - recall: 0.7663 - val_loss: 0.4174 - val_recall: 0.8177
# Epoch 35/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4650 - recall: 0.7706 - val_loss: 0.4311 - val_recall: 0.8287
# Epoch 36/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4642 - recall: 0.7778 - val_loss: 0.3895 - val_recall: 0.8122
# Epoch 37/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4704 - recall: 0.7633 - val_loss: 0.4667 - val_recall: 0.8398
# Epoch 38/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4670 - recall: 0.7791 - val_loss: 0.4367 - val_recall: 0.8343
# Epoch 39/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4636 - recall: 0.7700 - val_loss: 0.4082 - val_recall: 0.8122
# Epoch 40/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4647 - recall: 0.7791 - val_loss: 0.4124 - val_recall: 0.8122
# Epoch 41/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4617 - recall: 0.7663 - val_loss: 0.4200 - val_recall: 0.8177
# Epoch 42/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4663 - recall: 0.7682 - val_loss: 0.3797 - val_recall: 0.8066
# Epoch 43/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4610 - recall: 0.7676 - val_loss: 0.4081 - val_recall: 0.8177
# Epoch 44/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4608 - recall: 0.7694 - val_loss: 0.4160 - val_recall: 0.8232
# Epoch 45/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4606 - recall: 0.7730 - val_loss: 0.4163 - val_recall: 0.8177
# Epoch 46/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4603 - recall: 0.7712 - val_loss: 0.4250 - val_recall: 0.8177
# Epoch 47/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4591 - recall: 0.7772 - val_loss: 0.4391 - val_recall: 0.8287
# Epoch 48/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4640 - recall: 0.7706 - val_loss: 0.3895 - val_recall: 0.8011
# Epoch 49/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4587 - recall: 0.7712 - val_loss: 0.3785 - val_recall: 0.7956
# Epoch 50/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4594 - recall: 0.7706 - val_loss: 0.4420 - val_recall: 0.8287
# Epoch 51/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4583 - recall: 0.7712 - val_loss: 0.4028 - val_recall: 0.8122
# Epoch 52/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4579 - recall: 0.7669 - val_loss: 0.4935 - val_recall: 0.8453
# Epoch 53/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4590 - recall: 0.7651 - val_loss: 0.4064 - val_recall: 0.8177
# Epoch 54/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4563 - recall: 0.7760 - val_loss: 0.4114 - val_recall: 0.8232
# Epoch 55/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4599 - recall: 0.7718 - val_loss: 0.4329 - val_recall: 0.8287
# Epoch 56/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4564 - recall: 0.7772 - val_loss: 0.3992 - val_recall: 0.8232
# Epoch 57/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4577 - recall: 0.7730 - val_loss: 0.3988 - val_recall: 0.8066
# Epoch 58/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4576 - recall: 0.7676 - val_loss: 0.4013 - val_recall: 0.8066
# Epoch 59/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4576 - recall: 0.7791 - val_loss: 0.3805 - val_recall: 0.8066
# Epoch 60/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4545 - recall: 0.7760 - val_loss: 0.4485 - val_recall: 0.8398
# Epoch 61/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4555 - recall: 0.7742 - val_loss: 0.4493 - val_recall: 0.8232
# Epoch 62/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4552 - recall: 0.7706 - val_loss: 0.4445 - val_recall: 0.8287
# Epoch 63/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4549 - recall: 0.7791 - val_loss: 0.4126 - val_recall: 0.8287
# Epoch 64/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4577 - recall: 0.7748 - val_loss: 0.4292 - val_recall: 0.8232
# Epoch 65/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4530 - recall: 0.7694 - val_loss: 0.4037 - val_recall: 0.8177
# Epoch 66/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4550 - recall: 0.7785 - val_loss: 0.4479 - val_recall: 0.8287
# Epoch 67/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4555 - recall: 0.7730 - val_loss: 0.3937 - val_recall: 0.8177
# Epoch 68/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4534 - recall: 0.7748 - val_loss: 0.4082 - val_recall: 0.8177
# Epoch 69/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4548 - recall: 0.7785 - val_loss: 0.4645 - val_recall: 0.8398
# Epoch 70/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4523 - recall: 0.7785 - val_loss: 0.4192 - val_recall: 0.8177
# Epoch 71/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4545 - recall: 0.7809 - val_loss: 0.3846 - val_recall: 0.7956
# Epoch 72/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4557 - recall: 0.7663 - val_loss: 0.4175 - val_recall: 0.8177
# Epoch 73/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4537 - recall: 0.7791 - val_loss: 0.3861 - val_recall: 0.8066
# Epoch 74/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4520 - recall: 0.7778 - val_loss: 0.4235 - val_recall: 0.8232
# Epoch 75/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4556 - recall: 0.7700 - val_loss: 0.3371 - val_recall: 0.7293
# Epoch 76/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4549 - recall: 0.7712 - val_loss: 0.4349 - val_recall: 0.8287
# Epoch 77/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4531 - recall: 0.7748 - val_loss: 0.4126 - val_recall: 0.8232
# Epoch 78/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4579 - recall: 0.7639 - val_loss: 0.4804 - val_recall: 0.8508
# Epoch 79/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4521 - recall: 0.7809 - val_loss: 0.4031 - val_recall: 0.8232
# Epoch 80/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4515 - recall: 0.7706 - val_loss: 0.4320 - val_recall: 0.8287
# Epoch 81/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4574 - recall: 0.7803 - val_loss: 0.3610 - val_recall: 0.7735
# Epoch 82/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4506 - recall: 0.7797 - val_loss: 0.4408 - val_recall: 0.8232
# Epoch 83/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4494 - recall: 0.7706 - val_loss: 0.3760 - val_recall: 0.8066
# Epoch 84/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4505 - recall: 0.7766 - val_loss: 0.4093 - val_recall: 0.8287
# Epoch 85/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4500 - recall: 0.7706 - val_loss: 0.4372 - val_recall: 0.8287
# Epoch 86/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4501 - recall: 0.7712 - val_loss: 0.4576 - val_recall: 0.8453
# Epoch 87/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4499 - recall: 0.7833 - val_loss: 0.4061 - val_recall: 0.8122
# Epoch 88/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4489 - recall: 0.7821 - val_loss: 0.4396 - val_recall: 0.8232
# Epoch 89/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4503 - recall: 0.7742 - val_loss: 0.3869 - val_recall: 0.7956
# Epoch 90/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4506 - recall: 0.7724 - val_loss: 0.4467 - val_recall: 0.8287
# Epoch 91/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4480 - recall: 0.7724 - val_loss: 0.4311 - val_recall: 0.8287
# Epoch 92/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4479 - recall: 0.7778 - val_loss: 0.4823 - val_recall: 0.8508
# Epoch 93/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4498 - recall: 0.7797 - val_loss: 0.3903 - val_recall: 0.8122
# Epoch 94/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4516 - recall: 0.7803 - val_loss: 0.3887 - val_recall: 0.8011
# Epoch 95/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4477 - recall: 0.7803 - val_loss: 0.4107 - val_recall: 0.8232
# Epoch 96/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4505 - recall: 0.7766 - val_loss: 0.4079 - val_recall: 0.8177
# Epoch 97/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4498 - recall: 0.7712 - val_loss: 0.3683 - val_recall: 0.7845
# Epoch 98/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4496 - recall: 0.7821 - val_loss: 0.3684 - val_recall: 0.7901
# Epoch 99/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4478 - recall: 0.7724 - val_loss: 0.3952 - val_recall: 0.8232
# Epoch 100/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4452 - recall: 0.7791 - val_loss: 0.3894 - val_recall: 0.8177
# Epoch 101/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4444 - recall: 0.7754 - val_loss: 0.3731 - val_recall: 0.7956
# Epoch 102/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4505 - recall: 0.7730 - val_loss: 0.3661 - val_recall: 0.7845
# Epoch 103/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4463 - recall: 0.7730 - val_loss: 0.4868 - val_recall: 0.8453
# Epoch 104/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4446 - recall: 0.7845 - val_loss: 0.4553 - val_recall: 0.8453
# Epoch 105/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4468 - recall: 0.7748 - val_loss: 0.4075 - val_recall: 0.8232
# Epoch 106/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4473 - recall: 0.7785 - val_loss: 0.3934 - val_recall: 0.8232
# Epoch 107/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4470 - recall: 0.7760 - val_loss: 0.4737 - val_recall: 0.8508
# Epoch 108/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4442 - recall: 0.7809 - val_loss: 0.4109 - val_recall: 0.8232
# Epoch 109/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4457 - recall: 0.7682 - val_loss: 0.4188 - val_recall: 0.8287
# Epoch 110/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4448 - recall: 0.7766 - val_loss: 0.4484 - val_recall: 0.8398
# Epoch 111/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4444 - recall: 0.7778 - val_loss: 0.3989 - val_recall: 0.8232
# Epoch 112/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4437 - recall: 0.7815 - val_loss: 0.4418 - val_recall: 0.8232
# Epoch 113/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4433 - recall: 0.7760 - val_loss: 0.4644 - val_recall: 0.8453
# Epoch 114/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4436 - recall: 0.7815 - val_loss: 0.4240 - val_recall: 0.8287
# Epoch 115/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4412 - recall: 0.7815 - val_loss: 0.3989 - val_recall: 0.8232
# Epoch 116/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4424 - recall: 0.7682 - val_loss: 0.4692 - val_recall: 0.8508
# Epoch 117/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4434 - recall: 0.7772 - val_loss: 0.4384 - val_recall: 0.8343
# Epoch 118/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4432 - recall: 0.7797 - val_loss: 0.4202 - val_recall: 0.8343
# Epoch 119/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4434 - recall: 0.7833 - val_loss: 0.4270 - val_recall: 0.8343
# Epoch 120/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4435 - recall: 0.7833 - val_loss: 0.4197 - val_recall: 0.8232
# Epoch 121/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4422 - recall: 0.7742 - val_loss: 0.4593 - val_recall: 0.8398
# Epoch 122/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4486 - recall: 0.7827 - val_loss: 0.3554 - val_recall: 0.7569
# Epoch 123/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4471 - recall: 0.7778 - val_loss: 0.3971 - val_recall: 0.7901
# Epoch 124/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4429 - recall: 0.7748 - val_loss: 0.3997 - val_recall: 0.8177
# Epoch 125/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4438 - recall: 0.7833 - val_loss: 0.4039 - val_recall: 0.8287
# Epoch 126/150
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4409 - recall: 0.7791 - val_loss: 0.4034 - val_recall: 0.8287
# Epoch 127/150
# 64/64 [==============================] - 0s 8ms/step - loss: 0.4416 - recall: 0.7821 - val_loss: 0.3800 - val_recall: 0.8122
# Epoch 128/150
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4424 - recall: 0.7845 - val_loss: 0.4038 - val_recall: 0.8177
# Epoch 129/150
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4442 - recall: 0.7785 - val_loss: 0.3893 - val_recall: 0.8122
# Epoch 130/150
# 64/64 [==============================] - 1s 8ms/step - loss: 0.4439 - recall: 0.7778 - val_loss: 0.4398 - val_recall: 0.8398
# Epoch 131/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4425 - recall: 0.7730 - val_loss: 0.4746 - val_recall: 0.8564
# Epoch 132/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4442 - recall: 0.7772 - val_loss: 0.3966 - val_recall: 0.8066
# Epoch 133/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4411 - recall: 0.7930 - val_loss: 0.4058 - val_recall: 0.8122
# Epoch 134/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4407 - recall: 0.7688 - val_loss: 0.4033 - val_recall: 0.8177
# Epoch 135/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4389 - recall: 0.7778 - val_loss: 0.4561 - val_recall: 0.8398
# Epoch 136/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4436 - recall: 0.7900 - val_loss: 0.3748 - val_recall: 0.7901
# Epoch 137/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4412 - recall: 0.7785 - val_loss: 0.3782 - val_recall: 0.7901
# Epoch 138/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4393 - recall: 0.7815 - val_loss: 0.3613 - val_recall: 0.7790
# Epoch 139/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4406 - recall: 0.7706 - val_loss: 0.4015 - val_recall: 0.8122
# Epoch 140/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4405 - recall: 0.7742 - val_loss: 0.4408 - val_recall: 0.8287
# Epoch 141/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4372 - recall: 0.7875 - val_loss: 0.3526 - val_recall: 0.7348
# Epoch 142/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4431 - recall: 0.7748 - val_loss: 0.4437 - val_recall: 0.8343
# Epoch 143/150
# 64/64 [==============================] - 0s 7ms/step - loss: 0.4403 - recall: 0.7815 - val_loss: 0.4006 - val_recall: 0.8066
# Epoch 144/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4393 - recall: 0.7839 - val_loss: 0.4051 - val_recall: 0.8177
# Epoch 145/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4418 - recall: 0.7851 - val_loss: 0.3788 - val_recall: 0.8066
# Epoch 146/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4434 - recall: 0.7724 - val_loss: 0.3734 - val_recall: 0.7901
# Epoch 147/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4398 - recall: 0.7785 - val_loss: 0.3769 - val_recall: 0.8011
# Epoch 148/150
# 64/64 [==============================] - 0s 6ms/step - loss: 0.4413 - recall: 0.7712 - val_loss: 0.4588 - val_recall: 0.8508
# Epoch 149/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4425 - recall: 0.7797 - val_loss: 0.4548 - val_recall: 0.8398
# Epoch 150/150
# 64/64 [==============================] - 0s 5ms/step - loss: 0.4413 - recall: 0.7821 - val_loss: 0.3510 - val_recall: 0.7624

# %%
grid_model.best_score_ # best score according to the scoring function
# Out:
# 0.7748132015342876

# %%
grid_model.best_params_ # best parameters to get the best score
# Out:
# {'batch_size': 128,
#  'learn_rate': 0.003,
#  'optimizer': keras.optimizers.optimizer_v2.adam.Adam}

# %%
y_pred = grid_model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# [[672 124]
#  [ 58 146]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       796
#            1       0.54      0.72      0.62       204
#
#     accuracy                           0.82      1000
#    macro avg       0.73      0.78      0.75      1000
# weighted avg       0.84      0.82      0.83      1000

# %% [markdown]
# ### ROC (Receiver Operating Curve) and AUC (Area Under Curve) for grid_model

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='ANN')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6975375559576587

# %% [markdown]
# ## Final Model and Model Deployment

# %%
import pickle # to save the model or scalling parameters

pickle.dump(scaler, open("scaler_churn", 'wb')) # to save the scaler

# %%
tf.random.set_seed(42)
model = Sequential()

model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.003),
              loss="binary_crossentropy",
              metrics=["Recall"])

model.fit(x=X_train,
          y=y_train,
          validation_data=(X_test, y_test),
          callbacks=[early_stop, PlotLossesKerasTF()],
          batch_size=128,
          epochs=200,
          verbose=1,
          class_weight=class_weights)
# Out:
# Loss
# 	training         	 (min:    0.456, max:    0.660, cur:    0.456)
# 	validation       	 (min:    0.373, max:    0.654, cur:    0.448)
# recall
# 	training         	 (min:    0.543, max:    0.779, cur:    0.768)
# 	validation       	 (min:    0.623, max:    0.868, cur:    0.760)
# 71/71 [==============================] - 1s 13ms/step - loss: 0.4562 - recall: 0.7681 - val_loss: 0.4482 - val_recall: 0.7598
# Epoch 42: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = (model.predict(X_test) > .5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 32/32 [==============================] - 0s 3ms/step
# [[705  91]
#  [ 76 128]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.89       796
#            1       0.58      0.63      0.61       204
#
#     accuracy                           0.83      1000
#    macro avg       0.74      0.76      0.75      1000
# weighted avg       0.84      0.83      0.84      1000

# %%
model.save('model_churn.h5')

# %% [markdown]
# ### Prediction

# %%
single_customer = df.drop('Exited', axis=1).iloc[0]
single_customer
# Out:
# CreditScore            619.000
# Age                     42.000
# Tenure                   2.000
# Balance                  0.000
# NumOfProducts            1.000
# HasCrCard                1.000
# IsActiveMember           1.000
# EstimatedSalary     101348.880
# customer_value           3.000
# Geography_Germany        0.000
# Geography_Spain          0.000
# Gender_Male              0.000
# Name: 1, dtype: float64

# %%
single_customer1 = single_customer.copy()
single_customer1["Age"] = 40
single_customer1["Balance"] = 50000

# %%
single_customer1
# Out:
# CreditScore            619.000
# Age                     40.000
# Tenure                   2.000
# Balance              50000.000
# NumOfProducts            1.000
# HasCrCard                1.000
# IsActiveMember           1.000
# EstimatedSalary     101348.880
# customer_value           3.000
# Geography_Germany        0.000
# Geography_Spain          0.000
# Gender_Male              0.000
# Name: 1, dtype: float64

# %%
single_customer = scaler.transform(single_customer.values.reshape(-1, 12))
single_customer
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 0.5       , 0.        ,
#         0.        , 0.        ]])

# %%
single_customer1 = scaler.transform(single_customer1.values.reshape(-1, 12))
single_customer1
# Out:
# array([[0.538     , 0.2972973 , 0.2       , 0.20974249, 0.        ,
#         1.        , 1.        , 0.50673489, 0.5       , 0.        ,
#         0.        , 0.        ]])

# %%
model.predict(single_customer)
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[0.57118434]], dtype=float32)

# %%
df["Exited"].iloc[0]
# Out:
# 1

# %%
model.predict(single_customer1)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[0.40073773]], dtype=float32)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Comparison with ML

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %%
clf1 = RandomForestClassifier(random_state=42, class_weight="balanced") 
clf2 = SVC(probability=True, random_state=42, class_weight="balanced")
clf3 = LogisticRegression(random_state=42, class_weight="balanced")

# %%
# Initilaze the hyperparameters for each dictionary
param1 = {}
param1['classifier__n_estimators'] = [10, 50, 100, 250]
param1['classifier__max_depth'] = [5, 10, 20]
param1['classifier'] = [clf1]

param2 = {}
param2['classifier__C'] = [10**(-2+i) for i in range(5)]
param2['classifier'] = [clf2]

param3 = {}
param3['classifier__C'] = [10**(-2+i) for i in range(5)]
param3['classifier__penalty'] = ['l1', 'l2']
param3['classifier'] = [clf3]

# %%
pipeline = Pipeline([('classifier', clf1)]) # pipeline to combine the classifiers
params = [param1, param2, param3] # list of dictionaries to tune the hyperparameters

# %%
grid_model = GridSearchCV(pipeline, params, cv=5, n_jobs=-1,
                  scoring='recall').fit(X_train, y_train)

# %%
grid_model.best_params_ # best parameters to get the best score
# Out:
# {'classifier': RandomForestClassifier(class_weight='balanced', max_depth=5, n_estimators=250,
#                         random_state=42),
#  'classifier__max_depth': 5,
#  'classifier__n_estimators': 250}

# %%
grid_model.best_score_ # best score according to the scoring function
# Out:
# 0.7146722055955093

# %%
y_pred_proba = grid_model.predict_proba(X_test)[:, 1]
precisions, recalls, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot(recalls, precisions, label='RF')
plt.xlabel('recalls')
plt.ylabel('precisions')
plt.title('Precision-Recall curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.6695473293906559

# %%
y_pred = grid_model.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[643 153]
#  [ 51 153]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86       796
#            1       0.50      0.75      0.60       204
#
#     accuracy                           0.80      1000
#    macro avg       0.71      0.78      0.73      1000
# weighted avg       0.84      0.80      0.81      1000

# %% [markdown]
# ---
# ---
